# %%
using CairoMakie
using Distributions
using LinearAlgebra
using AlgebraOfGraphics
CairoMakie.activate!(type = "svg")
using Random

# %%
Random.seed!(7)
set_aog_theme!()

data = cumsum(randn(100, 101), dims = 2)

Edata = mean(data,dims=1)
fig, ax, = series(0:0.1:10, data, solid_color=:black,linewidth=0.5)
lines!(0:0.1:10, data[3,:], color=:black,linewidth=5)
hidedecorations!(ax)
hidespines!(ax)
save("quantfig.p"fig
# Out:
# Figure()
